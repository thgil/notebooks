# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# This file contains all the main external libs we'll use
from fastai.imports import *

# %%
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
PATH = "data/whales/"

# %%
sz=224
arch=resnet34

# %%
os.listdir(PATH)
# Out:
# ['tmp',
#  'train.zip',
#  'sample_submission.csv',
#  'models',
#  'train',
#  'test.zip',
#  'test',
#  'train.csv']

# %%
data = ImageClassifierData.from_csv(f'{PATH}', folder='train', csv_fname=f'{PATH}train.csv', tfms=tfms_from_model(arch, sz))

# %% [markdown]
# Lets look at what our class data actually looks like..

# %%
data.classes[:4]
# Out:
# ['new_whale', 'w_0013924', 'w_001ebbc', 'w_002222a']

# %%
len(data.classes)
# Out:
# 4251

# %% [markdown]
# This will be just a bunch of whale ids. 4251 of them!
#
# Lets see what our data looks like before we begin.

# %%
files = os.listdir(f'{PATH}train')[:5]
ims = [plt.imread(f'{PATH}train/{file}') for file in files]

# %%
ims[0].shape
# Out:
# (401, 1050, 3)

# %%
def plots(ims, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(f'Whale', fontsize=12)
        plt.imshow(ims[i]);
        
plots(ims,(40,30))

# %% [markdown]
# Looks simple enough! Lets dive in ;)
#
# We will start with a simple precomputed model to see if we stand a chance.

# %%
shutil.rmtree(f'{PATH}tmp', ignore_errors=True)

# %%
arch=resnet34
sz=299
bs=64
# tfms = tfms_from_model(resnet34, sz, aug_tfms=transforms_side_on, max_zoom=1.2)
# data = ImageClassifierData.from_csv(f'{PATH}', folder='train', csv_fname=f'{PATH}train.csv', tfms=tfms, bs=bs)
# learn = ConvLearner.pretrained(arch, data, precompute=True)
# learn.fit(0.01, 1)

# %%
label_csv = f'{PATH}train.csv'
n = len(list(open(label_csv)))-1
val_idxs = get_cv_idxs(n)

# %%
def get_data(sz):
    tfms = tfms_from_model(resnet34, sz, aug_tfms=transforms_top_down, max_zoom=1.05)
    return ImageClassifierData.from_csv(PATH, 'train', label_csv, tfms=tfms,
                                        val_idxs=val_idxs, test_name='test')

# %%
data = get_data(299)

# %%
x,y = next(iter(data.val_dl))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-36-58f4f6117e2c> in <module>()
# ----> 1 x,y = next(iter(data.val_dl))
#
# ~/notebooks/fastai/dataloader.py in __iter__(self)
#      82                 # avoid py3.6 issue where queue is infinite and can result in memory exhaustion
#      83                 for c in chunk_iter(iter(self.batch_sampler), self.num_workers*10):
# ---> 84                     for batch in e.map(self.get_batch, c): yield get_tensor(batch, self.pin_memory)
#      85
#
# ~/notebooks/fastai/dataloader.py in get_tensor(batch, pin)
#      16         return {k: get_tensor(sample, pin) for k, sample in batch.items()}
#      17     elif isinstance(batch, collections.Sequence):
# ---> 18         return [get_tensor(sample, pin) for sample in batch]
#      19     raise TypeError("batch must contain numbers, dicts or lists; found {}"
#      20                      .format(type(batch)))
#
# ~/notebooks/fastai/dataloader.py in <listcomp>(.0)
#      16         return {k: get_tensor(sample, pin) for k, sample in batch.items()}
#      17     elif isinstance(batch, collections.Sequence):
# ---> 18         return [get_tensor(sample, pin) for sample in batch]
#      19     raise TypeError("batch must contain numbers, dicts or lists; found {}"
#      20                      .format(type(batch)))
#
# ~/notebooks/fastai/dataloader.py in get_tensor(batch, pin)
#      10 def get_tensor(batch, pin):
#      11     if isinstance(batch, (np.ndarray, np.generic)):
# ---> 12         batch = T(batch).contiguous()
#      13         return batch.pin_memory() if pin else batch
#      14     elif isinstance(batch, string_classes): return batch
#
# ~/notebooks/fastai/core.py in T(a)
#      23         return torch.FloatTensor(a.astype(np.float32))
#      24     raise NotImplementedError(a.dtype)
# ---> 25 def T(a): return to_gpu(T_(a), async=True)
#      26
#      27 def create_variable(x, volatile, requires_grad=False):
#
# ~/notebooks/fastai/core.py in to_gpu(x, *args, **kwargs)
#      44 USE_GPU=True
#      45 def to_gpu(x, *args, **kwargs):
# ---> 46     return x.cuda(*args, **kwargs) if torch.cuda.is_available() and USE_GPU else x
#      47
#      48 def noop(*args, **kwargs): return
#
# ~/src/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# RuntimeError: cuda runtime error (59) : device-side assert triggered at /opt/conda/conda-bld/pytorch_1518244421288/work/torch/lib/THC/generic/THCTensorCopy.c:132

# %%
f_model = resnet34
learn = ConvLearner.pretrained(f_model, data)

# %%
lrf=learn.lr_find()
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  94%|█████████▍| 117/124 [02:11<00:07,  1.12s/it, loss=44.7]

# %%
learn.fit(0.5, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-b514438cb6e8> in <module>()
# ----> 1 learn.fit(0.5, 3, cycle_len=1, cycle_mult=2)
#
# ~/notebooks/fastai/learner.py in fit(self, lrs, n_cycle, wds, **kwargs)
#     250         self.sched = None
#     251         layer_opt = self.get_layer_opt(lrs, wds)
# --> 252         return self.fit_gen(self.model, self.data, layer_opt, n_cycle, **kwargs)
#     253
#     254     def warm_up(self, lr, wds=None):
#
# ~/notebooks/fastai/learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, use_clr_beta, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, **kwargs)
#     197         n_epoch = sum_geom(cycle_len if cycle_len else 1, cycle_mult, n_cycle)
#     198         return fit(model, data, n_epoch, layer_opt.opt, self.crit,
# --> 199             metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, **kwargs)
#     200
#     201     def get_layer_groups(self): return self.models.get_layer_groups()
#
# ~/notebooks/fastai/model.py in fit(model, data, epochs, opt, crit, metrics, callbacks, stepper, **kwargs)
#     135
#     136         if not all_val:
# --> 137             vals = validate(stepper, data.val_dl, metrics)
#     138             if epoch == 0: print(layout.format(*names))
#     139             print_stats(epoch, [debias_loss] + vals)
#
# ~/notebooks/fastai/model.py in validate(stepper, dl, metrics)
#     185         if isinstance(x,list): batch_cnts.append(len(x[0]))
#     186         else: batch_cnts.append(len(x))
# --> 187         loss.append(to_np(l))
#     188         res.append([f(preds.data,y) for f in metrics])
#     189     return [np.average(loss, 0, weights=batch_cnts)] + list(np.average(np.stack(res), 0, weights=batch_cnts))
#
# ~/notebooks/fastai/core.py in to_np(v)
#      40     if isinstance(v, Variable): v=v.data
#      41     if isinstance(v, torch.cuda.HalfTensor): v=v.float()
# ---> 42     return v.cpu().numpy()
#      43
#      44 USE_GPU=True
#
# ~/src/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/tensor.py in cpu(self)
#      43     def cpu(self):
#      44         r"""Returns a CPU copy of this tensor if it's not already on the CPU"""
# ---> 45         return self.type(getattr(torch, self.__class__.__name__))
#      46
#      47     def double(self):
#
# ~/src/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/cuda/__init__.py in type(self, *args, **kwargs)
#     394     def type(self, *args, **kwargs):
#     395         with device(self.get_device()):
# --> 396             return super(_CudaBase, self).type(*args, **kwargs)
#     397
#     398     __new__ = _lazy_new
#
# ~/src/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/_utils.py in _type(self, new_type, async)
#      36     if new_type.is_sparse:
#      37         raise RuntimeError("Cannot cast dense tensor to sparse tensor")
# ---> 38     return new_type(self.size()).copy_(self, async)
#      39
#      40
#
# RuntimeError: cuda runtime error (59) : device-side assert triggered at /opt/conda/conda-bld/pytorch_1518244421288/work/torch/lib/THC/generic/THCTensorCopy.c:70
